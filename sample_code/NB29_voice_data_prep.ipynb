# %% [markdown]
# ### preparing voice data clips for voice unit
# * use cv-corpus-12.0-2022-12-07 emglish collection
# * remove those speakers (client_id) that gender = 'other', OR have any down_votes > 0
# * even those that have clips with down_votes = 0, as long as the speaker even has one clip that received down_votes
# * in addition, for the younger speakers group, remove those speakers with less than 6 clips recorded
# * this reduced data volume from 90 GB to 2GB, speakers from 33806 to 1123, clips from 986571 to 15006

# %%
import pandas as pd
import numpy as np

# %%
cv_list = pd.read_csv('/Users/yingli/Downloads/cv-corpus-12.0-2022-12-07/en/train.tsv', sep='\t', \
    dtype = {'age':str, 'gender':str})

# %%
cv_list.nunique()
# Out:
# client_id      33806
# path          986571
# sentence      986571
# up_votes          23
# down_votes        10
# age                9
# gender             3
# accents            0
# locale             1
# segment            0
# dtype: int64

# %%
cv_list.drop(labels = ["accents", "segment", "locale"],axis =1,inplace=True)
cv_list.dropna(inplace = True)

# %%
cv_list.count()
# Out:
# client_id     698658
# path          698658
# sentence      698658
# up_votes      698658
# down_votes    698658
# age           698658
# gender        698658
# dtype: int64

# %%
remove1 = cv_list.query("down_votes > 0 or gender == 'other'").client_id.drop_duplicates()
df_merge = cv_list.merge(remove1, how = "outer",indicator = True, on="client_id")
df1 = df_merge.loc[df_merge["_merge"] == "left_only"].drop("_merge",axis =1)
df1.groupby(["age","gender"]).nunique()
# Out:
#                   client_id  path  sentence  up_votes  down_votes
# age       gender
# eighties  female          2    55        55         2           1
#           male            5    34        34         4           1
# fifties   female         76   496       496         5           1
#           male          161  1015      1015         6           1
# fourties  female        100   749       749         7           1
#           male          328  2038      2038         5           1
# seventies female         21   190       190         5           1
#           male           46   288       288         6           1
# sixties   female         57   601       601         5           1
#           male          101   676       676         4           1
# teens     female         80   812       812         5           1
#           male          301  2229      2229         7           1
# thirties  female        144  1290      1290         6           1
#           male          585  4343      4343         6           1
# twenties  female        214  1468      1468         5           1
#           male         1007  5871      5871        10           1

# %%
cv_list.shape, df1.shape
# Out:
# ((698658, 7), (22155, 7))

# %%
clients = cv_list.groupby(["client_id","age","gender"]).agg(
    up_vote_max = ('up_votes', 'max'),
    up_vote_min = ('up_votes', 'min'),
    down_vote_max = ('down_votes', 'max'),
    down_vote_min = ('down_votes', 'min'),
    num_up_vote = ('up_votes', 'nunique'),
    num_down_vote = ('down_votes', 'nunique'),
    num_clip = ('path', 'count')
).reset_index()

# %%
remove2 = clients.query("age != 'eighties' and age !='seventies' and num_clip <= 5").client_id.drop_duplicates()
df_merge = df1.merge(remove2, how = "outer",indicator = True, on="client_id")
df2 = df_merge.loc[df_merge["_merge"] == "left_only"].drop("_merge",axis =1)
df2.groupby(["age","gender"]).nunique()
# Out:
#                   client_id  path  sentence  up_votes  down_votes
# age       gender
# eighties  female          2    55        55         2           1
#           male            5    34        34         4           1
# fifties   female         32   351       351         4           1
#           male           57   647       647         6           1
# fourties  female         45   560       560         7           1
#           male          100  1286      1286         5           1
# seventies female         21   190       190         5           1
#           male           46   288       288         6           1
# sixties   female         23   464       464         5           1
#           male           38   448       448         4           1
# teens     female         42   677       677         5           1
#           male          111  1618      1618         7           1
# thirties  female         51   922       922         5           1
#           male          189  2995      2995         6           1
# twenties  female         71   967       967         4           1
#           male          291  3504      3504        10           1

# %%
cv_list.shape,df1.shape,df2.shape
# Out:
# ((698658, 7), (22155, 7), (15006, 7))

# %%
df2.path.nunique()/cv_list.shape[0]*90 # whole collection is about 90 GB in size
# Out:
# 1.9330487878189329

# %%
df2.groupby(["client_id", "age","gender"]).agg(
    clip_num = ('path', 'nunique')
).reset_index().sort_values(by="clip_num", ascending=False)
# Out:
#                                              client_id        age  gender  \
# 370  55e8921a6b0968107dcc6bad3e7cd2ab74b27ad0520581...   thirties    male
# 993  e5ec4ff8c5f24fd6cf0431dbc29fbf29ec565ea8c4455e...   thirties  female
# 270  40d9ed81ec9cd287017629cbe8e68a99eacec68020e3a2...    sixties  female
# 306  483ea02dad41028e327f5eb09a79faaa2f38eccad6b6ef...   thirties    male
# 192  2b8b16dd2a58a785a955c39a7d2377a8a7c7c68d17dbf1...      teens    male
# ..                                                 ...        ...     ...
# 972  e1a503f6d1601e5c5cd12426e1efde44a671ed1137d8eb...  seventies  female
# 768  b0fe0110971f06d859b66254cf6e7c73dbe1d484dbc5eb...  seventies    male
# 916  d40ae1a4614a236ffd9ccd55fd0af7eed9974b13756d18...  seventies    male
# 924  d5ed376f34311e655c695f1bbb2eb909375b2a34d3257e...  seventies  female
# 931  d6a7d6ded3e1e31263dea79b95f321e0be5dfc92eda649...  seventies    male
#
#      clip_num
# 370       261
# 993       134
# 270       116
# 306       105
# 192        97
# ..        ...
# 972         1
# 768         1
# 916         1
# 924         1
# 931         1
#
# [1124 rows x 4 columns]

# %%
df2.query("age == 'twenties' and gender == 'male'").groupby("client_id").up_votes.max().sort_values(ascending=False)
# Out:
# client_id
# 003199b017d556d7b9d5482c09f0889c8ca821a59ad396e3a7402ee9c941a76e4dd868c5a2e7d85ce6c49a45f60c3daaeb88156f10b6cab03ff829b781ad410d    16.0
# 6817e481dcca14382ea4b7d2b9ca94e9f103aa982eb772ed0b761c6081e9719afed25fef7e349c43737328861084b88a555ef0853fa7bcfd2539c405c463a85e    12.0
# 8308864c88b6df6ff45d803952f36b1c39b6835d7a71334405f1b340d2db9257edf52bd405807278f6dca161e01c79027982efeb44e62533a551c1b6f3ac8b25    12.0
# f933a62114e4da82128c41922ca8a1d6198c4cd1ff391d382d8002da33a65fcca653b55e8cb207b4682e8a3a3525ca239af9b769d54e2f31996ee9f5066b4079    10.0
# 3b97dd5c9db498daa7f62739105a62eeab8abd29b2765e3055ea9aed55f7bd85a0e7a4a5a61ffd24b32b88445c2fffa311b5a622fcd00166f84101306ec2134f     8.0
#                                                                                                                                     ...
# 68f1a3b82923bce610e0162d8c8dce1f985eb68d5b5778013117477413f659fb8b78bcad7125d9e9bb4d6d0754d3bc03b7fcaac54435dcf63f977301691ab7ca     2.0
# 6905fe4758eff3c02593cb6384fe8a9822d236e66a98fe1f3d798e88a3219b54b1647ae2c23d60851fc526923b95cfa9b9ad311abd2879ef2f9be86d8ead3358     2.0
# 6a0fb1baaf8d0c53c51f3b934143a3ddfe60422c47112e9fdd2b166259b982ca73daab1a30fbd46701cb28fd1922093e80a3ae3b6e56a3c6202cc216f815b511     2.0
# 6a272b94687d650ca8cdf48fb6cf781244f9436f4c63468ddb656be0179c50a15c2761c4f4e0af814f34a1a621b65ac0a8a0ad9508f8a680fe2af38c28ddf4c9     2.0
# 7a8749b1697ff3b5923774794122a1174a61366aad11cef0bfa9df55d8b83bfe34b27395a07e208b267f85c9c8987a0ffa1738c454157df397ae5899171458ec     2.0
# Name: up_votes, Length: 291, dtype: float64

# %%
df2.nunique()
# Out:
# client_id      1123
# path          15006
# sentence      15006
# up_votes         11
# down_votes        1
# age               8
# gender            2
# dtype: int64

# %%
df2.sentence.apply(lambda x: len(x)).describe()
# Out:
# count    15006.000000
# mean        60.350993
# std         19.471146
# min          4.000000
# 25%         46.000000
# 50%         61.000000
# 75%         75.000000
# max        169.000000
# Name: sentence, dtype: float64

# %%
df2.groupby("client_id").count().reset_index().sort_values( by = "up_votes", ascending = False).head(20)
# Out:
#                                               client_id  path  sentence  \
# 370   55e8921a6b0968107dcc6bad3e7cd2ab74b27ad0520581...   261       261
# 992   e5ec4ff8c5f24fd6cf0431dbc29fbf29ec565ea8c4455e...   134       134
# 270   40d9ed81ec9cd287017629cbe8e68a99eacec68020e3a2...   116       116
# 306   483ea02dad41028e327f5eb09a79faaa2f38eccad6b6ef...   105       105
# 192   2b8b16dd2a58a785a955c39a7d2377a8a7c7c68d17dbf1...    97        97
# 699   a33afddc9bfab2d5710efcb0a162d6e8e2ed092be3a59e...    94        94
# 128   1a7affcdbc38b0b348af446d34fb2b8796fee59b7346f8...    87        87
# 9     00dd747cffb223ea3095abc625f16e689d74e3c4c4871f...    87        87
# 343   50756554519563411e77bf15f3c85f2e15e134aecf1204...    84        84
# 1045  efcec6355fdb427f75173123b8865bdfa9f3f5949080cc...    67        67
# 447   6817e481dcca14382ea4b7d2b9ca94e9f103aa982eb772...    67        67
# 1033  ee09a1d87df4d4588cc3279db9a23a5633f4223dac0c80...    63        63
# 1034  ee0dd2cf4383159aea5f7d2d6919e6311cc2ea9bb1b6c7...    63        63
# 792   b662400ea9e9dcdcf61fa40d0d4bb1f311b056e02b4a07...    58        58
# 1020  eb20cff313b16ec667654febb89ea83e8d0db03d336cdb...    57        57
# 300   471d6cd137e066c8f16f9deb2508efc89505545b1778f3...    54        54
# 873   caa08462f9ee4310b1a7e8a43e59e25eb75fb4dd6676bc...    54        54
# 259   3d6b1877c393e2b5575cf7e5b6301467be00f08ea55104...    53        53
# 703   a399edb3054b996ac950b6df93318e952ceada381b1106...    53        53
# 172   25f1910f8f75dc0efbd81c6342efe3873dfd1de17c4863...    49        49
#
#       up_votes  down_votes  age  gender
# 370        261         261  261     261
# 992        134         134  134     134
# 270        116         116  116     116
# 306        105         105  105     105
# 192         97          97   97      97
# 699         94          94   94      94
# 128         87          87   87      87
# 9           87          87   87      87
# 343         84          84   84      84
# 1045        67          67   67      67
# 447         67          67   67      67
# 1033        63          63   63      63
# 1034        63          63   63      63
# 792         58          58   58      58
# 1020        57          57   57      57
# 300         54          54   54      54
# 873         54          54   54      54
# 259         53          53   53      53
# 703         53          53   53      53
# 172         49          49   49      49

# %%
df2.nunique()
# Out:
# client_id      1123
# path          15006
# sentence      15006
# up_votes         11
# down_votes        1
# age               8
# gender            2
# dtype: int64

# %%
df2.path.to_csv("voice_clips_list.csv", header=True,index=False)
#df2.to_csv("voice_clips_meta_data.csv", index=False)
