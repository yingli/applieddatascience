# %%
import pandas as pd
import numpy as np
import seaborn as sns 
from matplotlib import pyplot as plt
import matplotlib as mpl
from sklearn import metrics
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.neural_network import MLPClassifier

from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
sdg_names = pd.read_excel("Digital Science SDG training set searches.xlsx")
sdg_names
# Out:
#    Unnamed: 0  \
# 0         NaN
# 1         NaN
# 2        Goal
# 3           1
# 4           2
# 5           3
# 6           4
# 7           5
# 8           6
# 9           7
# 10          8
# 11          9
# 12         10
# 13         11
# 14         12
# 15         13
# 16         14
# 17         15
# 18         16
# 19         17
#
#    Each tab contains the keywords/phrases used for generating the training set.  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                Name
# 3                                          No Poverty
# 4                                         Zero Hunger
# 5                          Good Health and Well Being
# 6                                   Quality Education
# 7                                     Gender Equality
# 8                          Clean Water and Sanitation
# 9                         Affordable and Clean Energy
# 10                    Decent Work and Economic Growth
# 11            Industry, Innovation and Infrastructure
# 12                               Reduced Inequalities
# 13                 Sustainable Cities and Communities
# 14             Responsible Consumption and Production
# 15                                     Climate Action
# 16                                   Life Below Water
# 17                                       Life on Land
# 18             Peace, Justice and Strong Institutions
# 19                         Partnerships for the Goals
#
#                                            Unnamed: 2
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3             End poverty in all its forms everywhere
# 4   End hunger, achieve food security and improved...
# 5   Ensure healthy lives and promote well-being fo...
# 6   Ensure inclusive and equitable quality educati...
# 7   Achieve gender equality and empower all women ...
# 8   Ensure availability and sustainable management...
# 9   Ensure access to affordable, reliable, sustain...
# 10  Promote sustained, inclusive and sustainable e...
# 11  Build resilient infrastructure, promote inclus...
# 12       Reduce inequality within and among countries
# 13  Make cities and human settlements inclusive, s...
# 14  Ensure sustainable consumption and production ...
# 15  Take urgent action to combat climate change an...
# 16  Conserve and sustainably use the oceans, seas ...
# 17  Protect, restore and promote sustainable use o...
# 18  Promote peaceful and inclusive societies for s...
# 19  Strengthen the means of implementation and rev...

# %%
sdg_names = sdg_names.drop([0,1,2], axis=0)
sdg_names = sdg_names.set_axis(["sdg", "sdg_name", "sdg_definition"],axis=1, copy=False)
sdg_names
# Out:
#    sdg                                 sdg_name  \
# 3    1                               No Poverty
# 4    2                              Zero Hunger
# 5    3               Good Health and Well Being
# 6    4                        Quality Education
# 7    5                          Gender Equality
# 8    6               Clean Water and Sanitation
# 9    7              Affordable and Clean Energy
# 10   8          Decent Work and Economic Growth
# 11   9  Industry, Innovation and Infrastructure
# 12  10                     Reduced Inequalities
# 13  11       Sustainable Cities and Communities
# 14  12   Responsible Consumption and Production
# 15  13                           Climate Action
# 16  14                         Life Below Water
# 17  15                             Life on Land
# 18  16   Peace, Justice and Strong Institutions
# 19  17               Partnerships for the Goals
#
#                                        sdg_definition
# 3             End poverty in all its forms everywhere
# 4   End hunger, achieve food security and improved...
# 5   Ensure healthy lives and promote well-being fo...
# 6   Ensure inclusive and equitable quality educati...
# 7   Achieve gender equality and empower all women ...
# 8   Ensure availability and sustainable management...
# 9   Ensure access to affordable, reliable, sustain...
# 10  Promote sustained, inclusive and sustainable e...
# 11  Build resilient infrastructure, promote inclus...
# 12       Reduce inequality within and among countries
# 13  Make cities and human settlements inclusive, s...
# 14  Ensure sustainable consumption and production ...
# 15  Take urgent action to combat climate change an...
# 16  Conserve and sustainably use the oceans, seas ...
# 17  Protect, restore and promote sustainable use o...
# 18  Promote peaceful and inclusive societies for s...
# 19  Strengthen the means of implementation and rev...

# %%
text_df = pd.read_csv("/Users/yingli/Downloads/osdg-community-dataset-v21-09-30.csv", sep = "\t")
text_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32120 entries, 0 to 32119
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   doi              32120 non-null  object
#  1   text_id          32120 non-null  object
#  2   text             32120 non-null  object
#  3   sdg              32120 non-null  int64
#  4   labels_negative  32120 non-null  int64
#  5   labels_positive  32120 non-null  int64
#  6   agreement        32120 non-null  float64
# dtypes: float64(1), int64(3), object(3)
# memory usage: 1.7+ MB

# %% [raw]
# # older version of the data is "osdg-community-data-v2022-07-01.csv", has more records
# #text_df = pd.read_csv("/Users/yingli/Downloads/osdg-community-data-v2022-09-01.csv", sep = "\t")
# #text_df.set_axis(["nn"], axis = 'columns', inplace=True)
# #text_df.nn.apply(lambda x: x.split('\t'))

# %%
text_df = pd.read_csv("/Users/yingli/Downloads/osdg-community-data-v2023-01-01.csv", sep = "\t", quotechar='"')
text_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40062 entries, 0 to 40061
# Data columns (total 1 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   doi	text_id	text	sdg	labels_negative	labels_positive	agreement  40062 non-null  object
# dtypes: object(1)
# memory usage: 313.1+ KB

# %% [markdown]
# ### data cleaning

# %%
text_df = pd.read_csv("/Users/yingli/Downloads/osdg-community-data-v2023-01-01.csv", sep = "\t", quotechar='"')
col_names = text_df.columns.values[0].split('\t')
text_df[col_names] = text_df[text_df.columns.values[0]].apply(lambda x: pd.Series(str(x).split("\t")))
text_df.drop(text_df.columns.values[0],axis = 1, inplace=True)
text_df = text_df.astype({'sdg':int, 'labels_negative': int, 'labels_positive':int, 'agreement': float}, copy=True)
text_df = text_df.query("agreement > 0.5 and (labels_positive - labels_negative) > 2")
text_df.reset_index(inplace=True)
text_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24669 entries, 0 to 24668
# Data columns (total 8 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   index            24669 non-null  int64
#  1   doi              24669 non-null  object
#  2   text_id          24669 non-null  object
#  3   text             24669 non-null  object
#  4   sdg              24669 non-null  int64
#  5   labels_negative  24669 non-null  int64
#  6   labels_positive  24669 non-null  int64
#  7   agreement        24669 non-null  float64
# dtypes: float64(1), int64(4), object(3)
# memory usage: 1.5+ MB

# %% [markdown]
# ### detecting language in the text

# %%
from langdetect import detect
print(detect("War doesn't show who's right, just who's left."))
print(detect("Ein, zwei, drei, vier"))
print(detect('四个和尚没水喝'))
print(detect('今一はお前さん'))
# Out:
# en
# de
# zh-cn
# ja

# %% [markdown]
#  - add a column in data frame for the corresponding language

# %%
from langdetect import detect
text_df["lang"] = text_df["text"].apply(lambda x: detect(x))
text_df.lang.value_counts()
# Out:
# en    24620
# fr       40
# es        5
# de        1
# et        1
# fi        1
# id        1
# Name: lang, dtype: int64

# %% [markdown]
# ### should we filter out those non-english texts?

# %%
text_df.query("lang== 'fr'")["text"]
# Out:
# 152      Une telle decomposition par categorie UICN n'e...
# 581      Le papier discute ensuite les choix methodolog...
# 1556     Les problemes de sante mentale legers a modere...
# 3148     Cependant, le developpement de mecanismes de r...
# 5026     Par contre, on n’aper^oit pas une difference c...
# 5648     Moreover, a budget-neutral redistribution of f...
# 6191     Il existe une raison supplementaire pour mettr...
# 7160     A cette fin, il est divise en trois sections. ...
# 7364     Les taux d’emploi feminins reagissent aux vari...
# 7593     The emphasis is on understanding how increasin...
# 8619     Entre 2007 et 2012, le niveau de vie median de...
# 8661     Enfin, il analyse, a partir des Statistiques d...
# 8774     This paper looks at the features of good caree...
# 9387     La mise en oeuvre de l'enquete se fait de mani...
# 9718     Par ailleurs, les resultats suggerent que l’ef...
# 10179    La protection economique des femmes en age ava...
# 10425    "En particulier, ce qui importe le plus est l'...
# 10431    Les jeunes adultes ne trouvant pas de travail ...
# 11635    Les pays declarants consacrent 0.6 % a 1.8 % d...
# 12051    La derniere rubrique du document aborde les el...
# 13670    For males, we estimate an hourly earnings prem...
# 14776    Dans les economies bienveillantes, les salaire...
# 15444    Industry can contribute with solutions such as...
# 15879    Les programmes de developpement de l’agricultu...
# 17121    Better data and more analysis are an essential...
# 17469    Aucune intervention isolee ne sera a meme de g...
# 17672    Les negotiations se poursuivent en vue d’obten...
# 18021    Le faible nombre d’inscrits dans les filieres ...
# 18167    Toutefois, les prix du ble ayant beneficie ces...
# 18314    The paper concludes by discussing the conflict...
# 18872    Le present document est consacre a ces questio...
# 19787    Ces enfants sont souvent confrontes a de multi...
# 20341    La mesure la plus urgente consiste a mettre en...
# 21499    Ils representaient egalement un plus faible po...
# 22343    Le PISA 2015 montre que les resultats obtenus ...
# 23311    Toutefois, qu'ils soient hommes ou femmes, les...
# 23398    Plusieurs dispositifs d’assistance bilaterale ...
# 23754    Dans le cours de cette etude, les comparaisons...
# 24211    Ces obligations doivent etre respectees dans t...
# 24368    La part des creances douteuses dans les portef...
# Name: text, dtype: object

# %% [markdown]
#  - use str.find to locate the position of a substring in a string, negative return indicate not found

# %%
text_df[text_df["text"].apply(lambda x: x.find('四个全面')) > 0]["text"]
# Out:
# 18009    In China today,President Xi Jinping’s new gran...
# Name: text, dtype: object

# %%
t1 = text_df[text_df["text"].apply(lambda x: x.find('四个全面')) > 0]["text"].values[0]
print(t1 == text_df.iloc[18009].text)
print(t1 is text_df.iloc[18009].text)
print(t1 == text_df.iloc[18009].text.casefold())
print(t1.lower() == text_df.iloc[18009].text.casefold())
# Out:
# True
# True
# False
# True

# %%
print(t1.casefold())
# Out:
# in china today,president xi jinping’s new grand narrative is framed by the widely publicised ‘four comprehensives’ (四个全面, ‘sigequanmian’). this narrative aims to : 1.build a moderately prosperous society, 2. deepen reform, 3. govern the nation according to law, and 4. tighten party discipline. it is essentially a political narrative that tells a moral tale that legitimizes and glorifies the virtues of the present. it also attempts to shrug off mistakes of the previous dynasty. drawing on the legal disciplines of economic law, international comparative law and the a priori analytic method of legal narrative analysis, this paper provides a critical appraisal of the ‘four comprehensives’, paying special attention to how the four principal strands of the narrative shape the directions of china’s socialist rule of law reforms and governance.  key words: chinese law reform, four comprehensives, 四个全面, sigequanmian,socialist rule of law,legal narrative analysis, economic-law nexus, south china sea.

# %%
text = 'groß'

# convert text to lowercase using casefold()
print('Using casefold():', text.casefold()) 

# convert text to lowercase using lower()
print('Using lower():', text.lower())
# Out:
# Using casefold(): gross
# Using lower(): groß

# %%
text_df.iloc[3].text.lower()
# Out:
# 'the israel oceanographic and limnological research station monitors the quantity and quality of water along the coastline of the mediterranean sea. the nature and parks authority (npa) monitors water quality in rivers on behalf of the moep. mekorot and local authorities monitor drinking water quality under the supervision of the ministry of health. the ministry of health monitors effluent quality prior to its use in the agricultural sector.'

# %% [markdown]
#  - use google translate

# %%
from googletrans import Translator
t = Translator().detect('四个全面')
print(t.lang, t.confidence)
print(Translator().detect("War doesn't show who's right, just who's left."))
print(Translator().detect("Ein, zwei, drei, vier"))
print(Translator().detect('四个和尚没水喝'))
print(Translator().detect('今一はお前さん'))
# Out:
# zh-CN 1
# Detected(lang=en, confidence=1)
# Detected(lang=de, confidence=1)
# Detected(lang=zh-CN, confidence=1)
# Detected(lang=ja, confidence=1)

# %% [markdown]
#  - use fasttext to detect language
#  - it can return to k languages, by probability

# %%
import fasttext
model = fasttext.load_model('lid.176.ftz')
print(model.predict(t1, k=3))
print(model.predict("In China today,President Xi Jinping’s new grand narrative is framed by the widely publicised ‘four comprehensives’ (四个全面, ‘sigequanmian’)."))
print(model.predict('四个全面', k=3))
print(model.predict('الشمس تشرق', k=2))  # top 2 matching languages
print(model.predict("影響包含對氣候的變化以及自然資源的枯竭程度",k=2))  # top 2 matching languages
# Out:
# (('__label__en', '__label__fr', '__label__es'), array([0.87778687, 0.00653897, 0.00630662]))
# (('__label__en',), array([0.84054291]))
# (('__label__zh', '__label__ja'), array([0.68349081, 0.31656581]))
# (('__label__ar', '__label__fa'), array([0.98124713, 0.01265871]))
# (('__label__zh', '__label__fr'), array([9.99575794e-01, 2.11721170e-04]))
# Warning : `load_model` does not return WordVectorModel or SupervisedModel any more, but a `FastText` object which is very similar.

# %% [markdown]
#  - use SpaCy to tag part of speech

# %%
import spacy
import en_core_web_sm
from spacy_langdetect import LanguageDetector
nlp = spacy.load("en_core_web_sm")
nlp = en_core_web_sm.load()
doc = nlp("This is a sentence.")
print([(w.text, w.pos_) for w in doc])
text_content = "Er lebt mit seinen Eltern und seiner Schwester in Berlin."
doc = nlp(text_content) #3
print([(w.text, w.pos_) for w in doc])
doc = nlp(t1)
print([(w.text, w.pos_) for w in doc])
# Out:
# [('This', 'PRON'), ('is', 'AUX'), ('a', 'DET'), ('sentence', 'NOUN'), ('.', 'PUNCT')]
# [('Er', 'INTJ'), ('lebt', 'NOUN'), ('mit', 'NOUN'), ('seinen', 'NOUN'), ('Eltern', 'PROPN'), ('und', 'NOUN'), ('seiner', 'NOUN'), ('Schwester', 'PROPN'), ('in', 'ADP'), ('Berlin', 'PROPN'), ('.', 'PUNCT')]
# [('In', 'ADP'), ('China', 'PROPN'), ('today', 'NOUN'), (',', 'PUNCT'), ('President', 'PROPN'), ('Xi', 'PROPN'), ('Jinping', 'PROPN'), ('’s', 'PART'), ('new', 'ADJ'), ('grand', 'ADJ'), ('narrative', 'NOUN'), ('is', 'AUX'), ('framed', 'VERB'), ('by', 'ADP'), ('the', 'DET'), ('widely', 'ADV'), ('publicised', 'VERB'), ('‘', 'PUNCT'), ('four', 'NUM'), ('comprehensives', 'NOUN'), ('’', 'PUNCT'), ('(', 'PUNCT'), ('四个全面', 'NOUN'), (',', 'PUNCT'), ('‘', 'PUNCT'), ('sigequanmian', 'ADJ'), ('’', 'PUNCT'), (')', 'PUNCT'), ('.', 'PUNCT'), ('This', 'DET'), ('narrative', 'NOUN'), ('aims', 'VERB'), ('to', 'PART'), (':', 'PUNCT'), ('1.build', 'NUM'), ('a', 'DET'), ('moderately', 'ADV'), ('prosperous', 'ADJ'), ('society', 'NOUN'), (',', 'PUNCT'), ('2', 'NUM'), ('.', 'X'), ('deepen', 'ADJ'), ('reform', 'NOUN'), (',', 'PUNCT'), ('3', 'NUM'), ('.', 'X'), ('govern', 'VERB'), ('the', 'DET'), ('nation', 'NOUN'), ('according', 'VERB'), ('to', 'ADP'), ('law', 'NOUN'), (',', 'PUNCT'), ('and', 'CCONJ'), ('4', 'X'), ('.', 'X'), ('tighten', 'VERB'), ('Party', 'PROPN'), ('discipline', 'NOUN'), ('.', 'PUNCT'), ('It', 'PRON'), ('is', 'AUX'), ('essentially', 'ADV'), ('a', 'DET'), ('political', 'ADJ'), ('narrative', 'NOUN'), ('that', 'PRON'), ('tells', 'VERB'), ('a', 'DET'), ('moral', 'ADJ'), ('tale', 'NOUN'), ('that', 'PRON'), ('legitimizes', 'VERB'), ('and', 'CCONJ'), ('glorifies', 'VERB'), ('the', 'DET'), ('virtues', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('present', 'NOUN'), ('.', 'PUNCT'), ('It', 'PRON'), ('also', 'ADV'), ('attempts', 'VERB'), ('to', 'PART'), ('shrug', 'VERB'), ('off', 'ADP'), ('mistakes', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('previous', 'ADJ'), ('dynasty', 'NOUN'), ('.', 'PUNCT'), ('Drawing', 'VERB'), ('on', 'ADP'), ('the', 'DET'), ('legal', 'ADJ'), ('disciplines', 'NOUN'), ('of', 'ADP'), ('economic', 'ADJ'), ('law', 'NOUN'), (',', 'PUNCT'), ('international', 'ADJ'), ('comparative', 'ADJ'), ('law', 'NOUN'), ('and', 'CCONJ'), ('the', 'DET'), ('a', 'DET'), ('priori', 'ADJ'), ('analytic', 'ADJ'), ('method', 'NOUN'), ('of', 'ADP'), ('legal', 'ADJ'), ('narrative', 'NOUN'), ('analysis', 'NOUN'), (',', 'PUNCT'), ('this', 'DET'), ('paper', 'NOUN'), ('provides', 'VERB'), ('a', 'DET'), ('critical', 'ADJ'), ('appraisal', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('‘', 'PUNCT'), ('four', 'NUM'), ('comprehensives', 'NOUN'), ('’', 'PUNCT'), (',', 'PUNCT'), ('paying', 'VERB'), ('special', 'ADJ'), ('attention', 'NOUN'), ('to', 'ADP'), ('how', 'SCONJ'), ('the', 'DET'), ('four', 'NUM'), ('principal', 'ADJ'), ('strands', 'NOUN'), ('of', 'ADP'), ('the', 'DET'), ('narrative', 'NOUN'), ('shape', 'VERB'), ('the', 'DET'), ('directions', 'NOUN'), ('of', 'ADP'), ('China', 'PROPN'), ('’s', 'PART'), ('socialist', 'ADJ'), ('rule', 'NOUN'), ('of', 'ADP'), ('law', 'NOUN'), ('reforms', 'NOUN'), ('and', 'CCONJ'), ('governance', 'NOUN'), ('.', 'PUNCT'), (' ', 'SPACE'), ('Key', 'ADJ'), ('words', 'NOUN'), (':', 'PUNCT'), ('Chinese', 'ADJ'), ('law', 'NOUN'), ('reform', 'NOUN'), (',', 'PUNCT'), ('four', 'NUM'), ('comprehensives', 'NOUN'), (',', 'PUNCT'), ('四个全面', 'PROPN'), (',', 'PUNCT'), ('sigequanmian', 'PROPN'), (',', 'PUNCT'), ('socialist', 'ADJ'), ('rule', 'NOUN'), ('of', 'ADP'), ('law', 'NOUN'), (',', 'PUNCT'), ('legal', 'ADJ'), ('narrative', 'NOUN'), ('analysis', 'NOUN'), (',', 'PUNCT'), ('economic', 'ADJ'), ('-', 'PUNCT'), ('law', 'NOUN'), ('nexus', 'NOUN'), (',', 'PUNCT'), ('South', 'PROPN'), ('China', 'PROPN'), ('Sea', 'PROPN'), ('.', 'PUNCT')]

# %%
doc = nlp(t1)
for i, sent in enumerate(doc.sents):
    print(i, len(sent), sent)
# Out:
# 0 29 In China today,President Xi Jinping’s new grand narrative is framed by the widely publicised ‘four comprehensives’ (四个全面, ‘sigequanmian’).
# 1 32 This narrative aims to : 1.build a moderately prosperous society, 2. deepen reform, 3. govern the nation according to law, and 4. tighten Party discipline.
# 2 21 It is essentially a political narrative that tells a moral tale that legitimizes and glorifies the virtues of the present.
# 3 12 It also attempts to shrug off mistakes of the previous dynasty.
# 4 63 Drawing on the legal disciplines of economic law, international comparative law and the a priori analytic method of legal narrative analysis, this paper provides a critical appraisal of the ‘four comprehensives’, paying special attention to how the four principal strands of the narrative shape the directions of China’s socialist rule of law reforms and governance.
# 5 32 Key words: Chinese law reform, four comprehensives, 四个全面, sigequanmian,socialist rule of law,legal narrative analysis, economic-law nexus, South China Sea.

# %%
from nltk import stem

tokens =  ['narrative', 'comprehensives', 'publicised', 'moderately', 'prosperous', 'legitimizes', 'according', 'glorifies'] 

porter = stem.porter.PorterStemmer() # Porter stemmer
snowball = stem.snowball.EnglishStemmer() # Snowball stemmer
lancaster = stem.lancaster.LancasterStemmer() # Lancaster stemmer

print('Porter Stemmer:', [porter.stem(i) for i in tokens])
print('Snowball Stemmer:', [snowball.stem(i) for i in tokens])
print('Lancaster Stemmer:', [lancaster.stem(i) for i in tokens])
# Out:
# Porter Stemmer: ['narr', 'comprehens', 'publicis', 'moder', 'prosper', 'legitim', 'accord', 'glorifi']
# Snowball Stemmer: ['narrat', 'comprehens', 'publicis', 'moder', 'prosper', 'legitim', 'accord', 'glorifi']
# Lancaster Stemmer: ['nar', 'comprehend', 'publ', 'mod', 'prosp', 'legitim', 'accord', 'glor']

# %%
t2='start'
t2.startswith('S')
'w' in t2
# Out:
# False

# %% [raw]
# nltk.download()

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
import textblob

# %%
from sklearn.feature_extraction.text import CountVectorizer
docs = text_df.text
count_vectorizer = CountVectorizer()
count_vectorizer.fit(docs)  #print('vocabulary: ', count_vectorizer.vocabulary_)
count_vector = count_vectorizer.transform(docs) #print('vectors: ', count_vector.toarray())

# %%
docs = text_df.text
count_vectorizer = CountVectorizer()  # add stop_words = 'english' to remove stop words
count_vector_dense = count_vectorizer.fit_transform(docs).todense()
temp_df = pd.DataFrame(count_vector_dense, columns=count_vectorizer.get_feature_names_out())

# %%
term_freq = pd.DataFrame({"term": temp_df.columns.values, "freq" : temp_df.sum(axis=0)})

# %%
term_freq.freq.sum()
# Out:
# 2335467

# %%
docs.apply(lambda x: len(x.split())).sum()
# Out:
# 2351777

# %% [markdown]
# notice the difference - perhaps due to certain processing details such as handling special characters,

# %%
t1.split()
# Out:
# ['In',
#  'China',
#  'today,President',
#  'Xi',
#  'Jinping’s',
#  'new',
#  'grand',
#  'narrative',
#  'is',
#  'framed',
#  'by',
#  'the',
#  'widely',
#  'publicised',
#  '‘four',
#  'comprehensives’',
#  '(四个全面,',
#  '‘sigequanmian’).',
#  'This',
#  'narrative',
#  'aims',
#  'to',
#  ':',
#  '1.build',
#  'a',
#  'moderately',
#  'prosperous',
#  'society,',
#  '2.',
#  'deepen',
#  'reform,',
#  '3.',
#  'govern',
#  'the',
#  'nation',
#  'according',
#  'to',
#  'law,',
#  'and',
#  '4.',
#  'tighten',
#  'Party',
#  'discipline.',
#  'It',
#  'is',
#  'essentially',
#  'a',
#  'political',
#  'narrative',
#  'that',
#  'tells',
#  'a',
#  'moral',
#  'tale',
#  'that',
#  'legitimizes',
#  'and',
#  'glorifies',
#  'the',
#  'virtues',
#  'of',
#  'the',
#  'present.',
#  'It',
#  'also',
#  'attempts',
#  'to',
#  'shrug',
#  'off',
#  'mistakes',
#  'of',
#  'the',
#  'previous',
#  'dynasty.',
#  'Drawing',
#  'on',
#  'the',
#  'legal',
#  'disciplines',
#  'of',
#  'economic',
#  'law,',
#  'international',
#  'comparative',
#  'law',
#  'and',
#  'the',
#  'a',
#  'priori',
#  'analytic',
#  'method',
#  'of',
#  'legal',
#  'narrative',
#  'analysis,',
#  'this',
#  'paper',
#  'provides',
#  'a',
#  'critical',
#  'appraisal',
#  'of',
#  'the',
#  '‘four',
#  'comprehensives’,',
#  'paying',
#  'special',
#  'attention',
#  'to',
#  'how',
#  'the',
#  'four',
#  'principal',
#  'strands',
#  'of',
#  'the',
#  'narrative',
#  'shape',
#  'the',
#  'directions',
#  'of',
#  'China’s',
#  'socialist',
#  'rule',
#  'of',
#  'law',
#  'reforms',
#  'and',
#  'governance.',
#  'Key',
#  'words:',
#  'Chinese',
#  'law',
#  'reform,',
#  'four',
#  'comprehensives,',
#  '四个全面,',
#  'sigequanmian,socialist',
#  'rule',
#  'of',
#  'law,legal',
#  'narrative',
#  'analysis,',
#  'economic-law',
#  'nexus,',
#  'South',
#  'China',
#  'Sea.']

# %%
set(count_vectorizer.vocabulary_.keys())
# Out:
# {'systematized',
#  'regis2',
#  'abb',
#  'decided',
#  'berglund',
#  'synchronisation',
#  'categorise',
#  'alerted',
#  'hilber',
#  'robotization',
#  'portrayals',
#  'interconnecting',
#  'fundamentality',
#  'eligibility',
#  'vdab',
#  'potenza',
#  'pessimistic',
#  'inacio',
#  'juglans',
#  'coherent2',
#  'immoderate',
#  'tory',
#  'laced',
#  'cabg',
#  'hierarchy',
#  'yeates',
#  'steensen',
#  'traveling',
#  'micro',
#  'logistically',
#  'techies',
#  'fonn',
#  'chuvash',
#  'iccs',
#  'cozzi',
#  'topography',
#  'armvodkanal',
#  'erwin',
#  'ilibraiy',
#  'legitimate',
#  'optimized',
#  'storm',
#  'conferring',
#  'diagnose',
#  '195',
#  'upshot',
#  'surfers',
#  'categorizes',
#  'beneath',
#  'slaughtered',
#  'livelihoods',
#  'himself',
#  'signalized',
#  'statcubc',
#  'noncombat',
#  'geophysical',
#  'tactics',
#  'veracruz',
#  'ho',
#  'despair',
#  'synthesise',
#  'throughout',
#  'mlaka',
#  'primaiy',
#  'ambassadors',
#  'era',
#  'prepares',
#  'atca',
#  'stressful',
#  'algal',
#  'slaughtering',
#  'mfa',
#  'autre',
#  'recreationists',
#  '505',
#  'shallowness',
#  'rothchild',
#  'militaristic',
#  'iacac',
#  'destabilizes',
#  'murtin',
#  'economic',
#  'appliances',
#  'ignrm',
#  'agion',
#  'fvl6osti',
#  'annihilation',
#  'positing',
#  'uppermost',
#  'poder',
#  'marimuthu',
#  'striven',
#  'layoff',
#  'directs',
#  'landless',
#  '200440',
#  'altbeker',
#  'caracter',
#  'culled',
#  'needfor',
#  'oft',
#  'revitalisation',
#  'toddlers',
#  'venables',
#  'shrinks',
#  'delimitate',
#  'challenges',
#  'epeli',
#  'glass',
#  'kerzil',
#  'iot',
#  'leyersdorff',
#  'infra',
#  '154',
#  'true',
#  'adat',
#  'interconnection',
#  'nouns',
#  'haul',
#  'pprr',
#  'politic',
#  'constructivist',
#  'bencfitted',
#  'naples',
#  'polysaprob',
#  'tolbert',
#  'perfectionism',
#  'transgovernmental',
#  'inculcating',
#  'obligations',
#  'fab',
#  'lisette',
#  'solorio',
#  'protocol4',
#  'medical',
#  'marquez',
#  'faroese',
#  'hania',
#  'distilled',
#  'dolphin',
#  'neda',
#  'teutsch',
#  'levine',
#  'colouring',
#  'prioritized',
#  'maladministration',
#  'objectivity',
#  'stepfathers',
#  'taiwanese',
#  'universally',
#  'conversation',
#  'msa',
#  'unmatched',
#  'output',
#  'pretty',
#  'fursati',
#  'lavorel',
#  'readiness',
#  'pounds',
#  'ipeec',
#  'ddt',
#  'nepal',
#  'rosario',
#  'attorneys',
#  'statelessness',
#  'reappearance',
#  'lp',
#  'centers',
#  'lightweight',
#  'eftec',
#  'double',
#  'toole',
#  'scales',
#  'flynn',
#  'iwbs',
#  'hsbc',
#  'declaring',
#  'tdn',
#  'salvia',
#  'wavers',
#  'housework',
#  'imperatives',
#  'enlisting',
#  'establish',
#  'framing',
#  'travels',
#  'observatorio',
#  'additive',
#  'punctuality',
#  'constraint',
#  'embattled',
#  'ies',
#  'perpetuation',
#  'krishnan',
#  'refiirbishments',
#  '3104',
#  'johnsson',
#  'wellness',
#  'safepack',
#  'reprisal',
#  'september',
#  'visitor',
#  'moef',
#  'casos',
#  'courent',
#  'shoks',
#  'ipart',
#  'sdg15',
#  'reassignment',
#  'rain',
#  'discovering',
#  'burgin',
#  'venous',
#  'divisor',
#  'nomura',
#  'usitc',
#  'upfront',
#  'snakes',
#  'hanak',
#  'implicate',
#  'putrajaya',
#  'dmz',
#  'remember',
#  'ork',
#  'enteiprises',
#  'claw',
#  'jay',
#  '15mw',
#  'ansipra',
#  'layoffs',
#  'buoys',
#  'manuf',
#  'gland',
#  'adi',
#  'webster',
#  'reversals',
#  'lampur',
#  'aste',
#  'mattingly',
#  'ictsd',
#  'dislodge',
#  'subtext',
#  'diego',
#  'doxed',
#  'phication',
#  'thumb',
#  'regulation',
#  'olmstead',
#  'cooperating',
#  'culf',
#  'locks',
#  'prunus',
#  'berrie',
#  'v2v',
#  'descent',
#  'anm',
#  'eulex',
#  'instance',
#  'involuntarily',
#  'marketised',
#  '02',
#  'cursos',
#  'argentine',
#  'ridding',
#  'kasper',
#  'breakfast',
#  'vultures',
#  'patchwork',
#  'arm',
#  'gustafsson',
#  'statins',
#  'widespread',
#  'wrap',
#  'justi',
#  'engraissement',
#  'landraces',
#  'cawang',
#  '318',
#  'suspensions',
#  'competed',
#  'winning',
#  'documenta',
#  'dashboard',
#  'sf6',
#  'oblivious',
#  'sjstjja',
#  'got',
#  'malthusian',
#  'machakos',
#  'difficulty',
#  'initially',
#  'motors',
#  'ddg',
#  'cont',
#  'kruse',
#  'sluices',
#  'friendliness',
#  'pybum',
#  'corina',
#  'rao',
#  'slaves',
#  'maupin',
#  'emitters',
#  'timescale',
#  'synchronise',
#  'mofal',
#  'cells',
#  'enrolling',
#  'criticized',
#  'waikato',
#  'insa',
#  'owner',
#  'rpjmn',
#  'featherman',
#  'reasserting',
#  'lyft',
#  'nandhini',
#  'disqualifying',
#  'rides',
#  'draught',
#  'severances',
#  'moulded',
#  'martin',
#  'ii4',
#  'sterilisation',
#  'oliver',
#  'au',
#  'causality',
#  'liverpool',
#  'juenger',
#  'spedfic',
#  'malmsheimer',
#  'iea',
#  'attractive',
#  'tlpozh03',
#  'salamanca',
#  'above',
#  'castration',
#  'listings',
#  'carlson',
#  'floodplains',
#  'trolley',
#  'layard',
#  'andenas',
#  'adaptively',
#  'exurban',
#  'tonsils',
#  'higashida',
#  'entrusted',
#  'occupation',
#  'rced',
#  'tacitly',
#  'antiracist',
#  'orientation',
#  'nirpc',
#  'discontent',
#  'transcend',
#  'superconducting',
#  'ldrarldnelyftet',
#  'casado',
#  '208',
#  'heaps',
#  'continually',
#  'bbc',
#  'kindergartens',
#  'zambia92',
#  'nimby',
#  'pcf',
#  'institutionalise',
#  'rath',
#  'trenchant',
#  'constitutionalization',
#  'tanzi',
#  'lehmacher',
#  'nonlinear',
#  'xhtml',
#  'decouple',
#  'chanam',
#  'poised',
#  'demanders',
#  'first',
#  'broad',
#  'indefinite',
#  'himanshu',
#  'joaquin',
#  '258',
#  'professionalize',
#  'referendum',
#  'stretches',
#  'cloves',
#  'wepia',
#  'lbc',
#  'cesspit',
#  'gvc',
#  'und',
#  'headlines',
#  'insumos',
#  'modeling',
#  'incident',
#  'trouves',
#  'celle',
#  'diokno',
#  'mdls',
#  'infact',
#  'taboos',
#  'initiative',
#  '680',
#  'frank',
#  'text',
#  'diverse',
#  'prosecuting',
#  'defendants',
#  'bargains',
#  'messaging',
#  'mgc600',
#  'ultimately',
#  'ohrid',
#  '703',
#  'dropbox',
#  '788',
#  'hogskoleradet',
#  'illegitimate',
#  'appropriating',
#  'interrelate',
#  'mandalay',
#  'naturalized',
#  'mezzanine',
#  'zoommeer',
#  'liconsa',
#  'ejemplo',
#  'annals',
#  'lenaerts',
#  'couple',
#  'yr1',
#  'mcnicoll',
#  'cmd',
#  'warden',
#  'foothold',
#  'overdrawn',
#  'jin',
#  'h0st',
#  '041',
#  'neoliberal',
#  'sympathetic',
#  'derechos',
#  'renovated',
#  'searchable',
#  'fixated',
#  'propordonately',
#  '1995a',
#  'changer',
#  'brookings',
#  'activators',
#  'qbwa',
#  'announced',
#  'demanded',
#  'refugee',
#  'moafwe',
#  'cleaned',
#  'throughput',
#  'brill',
#  'lng',
#  'mgnrega',
#  'asthe',
#  'bordered',
#  'jerusalem',
#  'counterinsurgent',
#  'uemoa',
#  'ecolabelling',
#  'undp',
#  '434',
#  'leisure',
#  '548',
#  'diseases',
#  'operation',
#  'extortive',
#  'erratic',
#  'kopacki',
#  'flourished',
#  'tsang',
#  'occupancy',
#  'reaped',
#  'leachate',
#  'redford',
#  'swap',
#  'disseminated',
#  'murambi',
#  'rebates',
#  'vandenbroucke',
#  'indexed',
#  'negro',
#  'amnes',
#  'adrenal',
#  'wallette',
#  'instantiated',
#  'topsoil',
#  'daylighting',
#  'cable',
#  'szabo',
#  'users11',
#  'odier',
#  'hazell',
#  'document',
#  'dozen',
#  'bie',
#  'agri',
#  'st',
#  'assurances',
#  'boulders',
#  'courtesy',
#  'hagler',
#  'commitment',
#  'plants36',
#  'ciett',
#  'gestidn',
#  '304',
#  'cajas',
#  'leveque',
#  'draws',
#  'dgal',
#  'chaman',
#  'koper',
#  'professionally',
#  'ekf',
#  'tfr',
#  'cohesive',
#  'bravo',
#  'uzbeks',
#  'coin',
#  'relinquishing',
#  'manages',
#  'maayan',
#  'metabolic',
#  'unsanctioned',
#  'deepening',
#  'poorly',
#  'posttransfer',
#  'cibubur',
#  'track',
#  'absorptive',
#  'smas',
#  '202002',
#  'loaded',
#  'increased',
#  'evangelicals',
#  'moms',
#  'pcdd',
#  'appearing',
#  'subcontracted',
#  'doubles',
#  'acute',
#  'sept',
#  'outlined',
#  'inclinations',
#  'presumes',
#  'wentworth',
#  'notamment',
#  'unprecedented',
#  'proigualdad',
#  'refutes',
#  'chioggia',
#  'forwarding',
#  'healthbridge',
#  'neumann',
#  'iding',
#  'reviewable',
#  'ratifications',
#  'ineed',
#  'ann',
#  'objection',
#  'uasin',
#  'naloxone',
#  'kariba',
#  '462',
#  'ofperformance',
#  'pcp',
#  'waddcn',
#  'pawnshops',
#  '848',
#  'evidente',
#  'dinaric',
#  'ang',
#  'deals',
#  'strathclyde',
#  'caatinga',
#  'ashamed',
#  'dosage',
#  '2008a',
#  'philipson',
#  'ruom',
#  'rape',
#  '006',
#  'orks',
#  'bay',
#  'som',
#  'prestemon',
#  'hipc',
#  'cigarette',
#  'kossoy',
#  'bribery',
#  'yaniv',
#  'identifies',
#  'contributor',
#  'kellomaki',
#  'pentru',
#  'prepayment',
#  'starve',
#  'mankiw',
#  'uptake',
#  'discredit',
#  '9496',
#  'arbetsfdrmedlingen',
#  'iufm',
#  'destructions',
#  'greenhouse',
#  'puras',
#  'ca',
#  'counternarratives',
#  'insubstantial',
#  'subsidiary',
#  'deis',
#  'mondial',
#  'csis',
#  'billion',
#  'discrepancies',
#  'friendship',
#  'extinctions',
#  'terrorism',
#  'succession',
#  'ibm',
#  'laval',
#  'ipps',
#  'dimensionality',
#  'arenas',
#  'zuo',
#  'areas4',
#  'obtains',
#  'gibs',
#  'enlaces',
#  'icbf',
#  'unidocentes',
#  'chad',
#  'kjell',
#  'eec',
#  'adour',
#  '29300',
#  'exposing',
#  'shadow',
#  'glover',
#  'territoires',
#  'tamil',
#  'upgrade',
#  'anaesthetists',
#  'e_it',
#  '349',
#  'gentilini',
#  'theoretical',
#  'cumulates',
#  'sibling',
#  'press',
#  'ept',
#  'bunkered',
#  'moternol',
#  'requested',
#  'layered',
#  'creatures',
#  'nok11',
#  'carework',
#  'bolstered',
#  'phrase',
#  'aromatic',
#  'specification',
#  'alterman',
#  'riesgos',
#  'ebwa',
#  'purchase',
#  'vindication',
#  'mutation',
#  'backstop',
#  'quintile',
#  'plateaus',
#  'xate',
#  'trader',
#  'odinafrica',
#  'generalisable',
#  '0110003',
#  'adpf',
#  'diffusionist',
#  'flemandez',
#  'exogeneity',
#  'rectal',
#  'forfits',
#  'divise',
#  'moldovan',
#  'swim',
#  'quercus',
#  'immovable',
#  'teaches',
#  'abroad',
#  'zoos',
#  'lazio',
#  'codeine',
#  'bundesnetzagentur',
#  'heathland',
#  'atyrau',
#  'detractors',
#  '2015e',
#  '2017d',
#  'overruled',
#  'belgium',
#  'multifarious',
#  'aifa',
#  'gmi',
#  'rosenholtz',
#  'krasnoyarsk',
#  'convulsively',
#  '13',
#  'irradiance',
#  'justifying',
#  'ejf',
#  'zetter',
#  'fairgrieve',
#  'janatass',
#  'technification',
#  'asub',
#  'yeah',
#  'marie',
#  'spalding',
#  'applicability',
#  'action',
#  'heike',
#  'baskin',
#  'manufactured',
#  'legalistic',
#  'degression',
#  'developable',
#  'budget',
#  'jeopardizing',
#  'scatter',
#  'biotechnology',
#  'matthews',
#  'ultimum',
#  'interagir',
#  'altamirano',
#  'quetzaltenango',
#  'clouded',
#  'bclc',
#  'strathmore',
#  'sale',
#  'supaul',
#  'regressions',
#  'joblessness',
#  'oh',
#  'mes',
#  'amalgamate',
#  'impair',
#  'kinshasa',
#  'violences',
#  'strategies',
#  'counted',
#  'raises',
#  'hedlund',
#  'perfectly',
#  'nwrs2',
#  'multiorgans',
#  'roughness',
#  'tertilt',
#  'tostan',
#  'discusses',
#  'mays',
#  'ksrkjarvi',
#  'found',
#  'retro',
#  'fullerton',
#  'antitrafficking',
#  'cannibalizing',
#  'variant',
#  'halogenated',
#  'abstractin',
#  'phwrs',
#  'vis',
#  'sociotechnical',
#  'inward',
#  'speeding',
#  'hypothesised',
#  'addicted',
#  'ncea',
#  'dialectical',
#  'football',
#  'pci',
#  'telle',
#  'fennoscandic',
#  'hyperlinks',
#  'asymmetrical',
#  'necessite',
#  'diversifolia',
#  'maikets',
#  'everlasting',
#  'disengaged',
#  'smacking',
#  'corrupting',
#  'dissipated',
#  'yarmouk',
#  'consumption2',
#  'gold',
#  'rebours',
#  'censure',
#  'share',
#  'aimed',
#  'scarcely',
#  'wariness',
#  'transfusion',
#  'abolition',
#  'petrochemical',
#  'chilean',
#  'iza',
#  'regard',
#  'faction',
#  'rhiney',
#  'rackets',
#  'rings',
#  'dushanbe',
#  'eukaryotes',
#  'obedience',
#  'surged',
#  'syke',
#  'ytrillion',
#  'poesoro',
#  'justifications',
#  '291',
#  'grouping',
#  '1904',
#  'cosos',
#  'gpp',
#  'radiological',
#  '___________________________',
#  'paras',
#  'context',
#  'proyecto',
#  '981',
#  'cimmyt',
#  'phonological',
#  'automating',
#  'rescaurant',
#  'appraises',
#  'tina',
#  'threshold',
#  'oftrustees',
#  'paz',
#  'hse',
#  'doolittle',
#  'fascinate',
#  'nakicenovic',
#  'iranians',
#  '0409',
#  'lorsqu',
#  'grasses',
#  '025',
#  'forcings',
#  'dimitris',
#  'values',
#  'singaporeans',
#  'objectifying',
#  'limitations',
#  'secured',
#  'designated',
#  'setapa',
#  'wbi',
#  'vaw',
#  'vande',
#  'homogeneity',
#  'mishra',
#  'mosaics',
#  'keynesian',
#  '5pp',
#  'transmitted',
#  'staples',
#  'robano',
#  'laun',
#  'duplicate',
#  'offre',
#  'penh',
#  'drip',
#  'edu',
#  'defenders',
#  'barbados',
#  'colombia',
#  'parisi',
#  '1954',
#  'consolidation',
#  'everybody',
#  'positivists',
#  'export',
#  'comprehensives',
#  'becaus',
#  'stigmatisation',
#  'hew',
#  'ejidos',
#  '3a',
#  'tj',
#  'hovgaard',
#  'kuhl',
#  'yukara',
#  'estas',
#  'obtain',
#  'underling',
#  'aumann',
#  'administratively',
#  'intermittency',
#  'jpon',
#  'duties',
#  'antiquated',
#  'underthe',
#  'intercommunalites',
#  'zoller',
#  'herds',
#  'sexes',
#  'usd90',
#  '60s',
#  'yr45',
#  'prohibit',
#  '4s1',
#  '3r',
#  'thriff',
#  'slowly',
#  'php7articlel',
#  'courtis',
#  'hlw',
#  'implementation',
#  'talking',
#  'assignment',
#  'dialogic',
#  'bounce',
#  'juarez',
#  'dinh',
#  'ant',
#  'marketability',
#  'isis',
#  'primaries',
#  'ifis',
#  'unfilled',
#  'deborah',
#  'sculptor',
#  'vocal',
#  'silt',
#  'retrenching',
#  'namsan',
#  'classical',
#  'sianesi',
#  'flaps',
#  'supervision',
#  'aifs',
#  'fault',
#  'discretionality',
#  'someone',
#  'regretful',
#  'wiki',
#  'reelection',
#  'geared',
#  'eptnm',
#  'metabolizes',
#  'symptoms',
#  'preto',
#  'appropriately',
#  'rechts',
#  '4j',
#  'allain',
#  'dreze',
#  'heifer',
#  'sword',
#  'stray',
#  'caern',
#  'noodt',
#  'exculpate',
#  'quahog',
#  'llece',
#  'ssf',
#  'sober',
#  'linz',
#  'taiex',
#  'masked',
#  'retiring',
#  'petition',
#  'correlates',
#  'schwabish',
#  'denver',
#  'rester',
#  'reeves',
#  'san',
#  'malfunctioning',
#  'tracer',
#  'vans',
#  'barely',
#  'playground',
#  'teles',
#  'resembling',
#  'waite',
#  'faaij',
#  'sizeable',
#  'disorientation',
#  ...}

# %%
term_freq.loc['sea']
# Out:
# term    sea
# freq    387
# Name: sea, dtype: object

# %%
term_freq.sort_values(by="freq", ascending=False)
# Out:
#                     term    freq
# the                  the  143100
# of                    of   95834
# and                  and   93357
# in                    in   67152
# to                    to   64701
# ...                  ...     ...
# cheering        cheering       1
# chekani          chekani       1
# microscopes  microscopes       1
# microscope    microscope       1
# oountry          oountry       1
#
# [45738 rows x 2 columns]

# %%
count_vectorizer.vocabulary_.get(u'women')
# Out:
# 45152

# %%
count_vectorizer.get_feature_names_out()[count_vectorizer.get_feature_names_out() == "from"]
# Out:
# array(['from'], dtype=object)

# %%
np.count_nonzero(count_vector.toarray())
# Out:
# 1647396

# %%
# proportion of non-zeros
np.count_nonzero(count_vector.toarray())/(count_vector.shape[0]*count_vector.shape[1])
# Out:
# 0.0014600552559492562

# %%
print('vector shape: ', count_vector.shape)
print('vocabulary size: ' , len(count_vectorizer.vocabulary_))
# Out:
# vector shape:  (24669, 45738)
# vocabulary size:  45738

# %%
# load in all the modules we're going to need
import nltk, re, string, collections
from nltk.util import ngrams # function for making ngrams
#doc = text_df.iloc[0].text
docs = text_df.text

# %%
count_vectorizer.vocabulary_
# Out:
# {'from': 17320,
#  'gender': 17817,
#  'perspective': 31409,
#  'paulgaard': 30974,
#  'points': 32035,
#  'out': 30158,
#  'that': 41221,
#  'the': 41229,
#  'labour': 23893,
#  'markets': 25859,
#  'of': 29487,
#  'fishing': 16605,
#  'villages': 44151,
#  'have': 19212,
#  'been': 5401,
#  'highly': 19611,
#  'segregated': 37317,
#  'in': 20921,
#  'terms': 41095,
#  'existence': 15618,
#  'male': 25572,
#  'jobs': 22833,
#  'and': 3469,
#  'female': 16283,
#  'however': 20021,
#  'new': 28504,
#  'business': 6873,
#  'opportunities': 29841,
#  'led': 24333,
#  'to': 41630,
#  'population': 32228,
#  'peripheral': 31312,
#  'areas': 4044,
#  'now': 29057,
#  'working': 45203,
#  'service': 37557,
#  'industry': 21264,
#  'former': 17023,
#  'boys': 6375,
#  'girls': 18111,
#  'are': 4040,
#  'doing': 13104,
#  'same': 36665,
#  'indicates': 21161,
#  'change': 7938,
#  'because': 5370,
#  'traditional': 41927,
#  'boundaries': 6336,
#  'between': 5660,
#  'women': 45152,
#  'men': 26434,
#  'work': 45189,
#  'being': 5451,
#  'crossed': 10661,
#  'but': 6886,
#  'fact': 15924,
#  'young': 45515,
#  'people': 31222,
#  'still': 39477,
#  'represents': 35351,
#  'continuity': 9894,
#  'with': 45094,
#  'past': 30879,
#  '2002': 562,
#  '102': 114,
#  'when': 44881,
#  'refers': 34717,
#  'traditions': 41931,
#  'she': 37760,
#  'expectations': 15661,
#  'adults': 2498,
#  'participate': 30797,
#  'adult': 2491,
#  'culture': 10829,
#  'thus': 41450,
#  'these': 41327,
#  'traditionally': 41929,
#  'no': 28728,
#  'actual': 2296,
#  'youth': 45525,
#  'as': 4217,
#  'described': 11939,
#  'earlier': 13647,
#  '2015': 658,
#  'concludes': 9389,
#  'some': 38686,
#  'norway': 28980,
#  'school': 36968,
#  'is': 22403,
#  'foreign': 16946,
#  'time': 41523,
#  'waster': 44590,
#  'stealing': 39364,
#  'who': 44923,
#  'should': 37895,
#  'instead': 21680,
#  'spend': 38957,
#  'their': 41248,
#  'on': 29700,
#  'what': 44866,
#  'considered': 9662,
#  'be': 5337,
#  'real': 34274,
#  'average': 4778,
#  'figure': 16456,
#  'also': 3182,
#  'masks': 25944,
#  'large': 24079,
#  'differences': 12331,
#  'across': 2252,
#  'regions': 34862,
#  'kazakhstan': 23249,
#  'number': 29174,
#  'annual': 3594,
#  'contacts': 9799,
#  'ranges': 34058,
#  'astana': 4413,
#  'mangystau': 25685,
#  'parts': 30840,
#  'likely': 24707,
#  'very': 44010,
#  'limited': 24735,
#  'access': 2100,
#  'primary': 32867,
#  'care': 7283,
#  'addition': 2358,
#  'poor': 32189,
#  'coverage': 10421,
#  'outpatient': 30207,
#  'prescription': 32738,
#  'medicines': 26319,
#  'limits': 24741,
#  'both': 6303,
#  'effectiveness': 13976,
#  'appeal': 3811,
#  'at': 4447,
#  'phc': 31560,
#  'level': 24515,
#  'findings': 16529,
#  'consistent': 9676,
#  'previous': 32840,
#  'examined': 15492,
#  'wage': 44437,
#  'inequality': 21285,
#  'countries': 10354,
#  'blau': 5980,
#  'khan': 23389,
#  '2005': 571,
#  'fournier': 17117,
#  'koske': 23675,
#  '2012': 628,
#  'returns': 35717,
#  'education': 13916,
#  'found': 17100,
#  'an': 3397,
#  'important': 20849,
#  'role': 36150,
#  'explaining': 15715,
#  'rise': 35995,
#  'earnings': 13660,
#  'see': 37277,
#  'autor': 4740,
#  '2014': 648,
#  'magnitude': 25468,
#  'contribution': 9955,
#  'quite': 33847,
#  'small': 38407,
#  'two': 42544,
#  'types': 42555,
#  'explanation': 15717,
#  'commonly': 9057,
#  'proposed': 33277,
#  'literature': 24849,
#  'first': 16582,
#  'emphasises': 14371,
#  'relative': 35035,
#  'supply': 40207,
#  'demand': 11640,
#  'for': 16900,
#  'skills': 38281,
#  'characteristics': 7986,
#  'lower': 25170,
#  'net': 28453,
#  'get': 17980,
#  'higher': 19601,
#  'rewards': 35823,
#  'second': 37195,
#  'played': 31890,
#  'by': 6918,
#  'market': 25848,
#  'institutions': 21717,
#  'such': 40001,
#  'minimum': 26941,
#  'wages': 44442,
#  'degree': 11534,
#  'unionisation': 43144,
#  'rules': 36399,
#  'governing': 18383,
#  'bargaining': 5164,
#  'israel': 22483,
#  'oceanographic': 29429,
#  'limnological': 24743,
#  'research': 35425,
#  'station': 39320,
#  'monitors': 27392,
#  'quantity': 33778,
#  'quality': 33766,
#  'water': 44606,
#  'along': 3162,
#  'coastline': 8701,
#  'mediterranean': 26327,
#  'sea': 37122,
#  'nature': 28171,
#  'parks': 30754,
#  'authority': 4700,
#  'npa': 29066,
#  'rivers': 36035,
#  'behalf': 5426,
#  'moep': 27271,
#  'mekorot': 26387,
#  'local': 24958,
#  'authorities': 4699,
#  'monitor': 27386,
#  'drinking': 13369,
#  'under': 42828,
#  'supervision': 40188,
#  'ministry': 26953,
#  'health': 19298,
#  'effluent': 13995,
#  'prior': 32901,
#  'its': 22551,
#  'use': 43586,
#  'agricultural': 2778,
#  'sector': 37228,
#  'chapters': 7973,
#  'discussed': 12666,
#  'ways': 44650,
#  'make': 25538,
#  'food': 16876,
#  'systems': 40551,
#  'more': 27490,
#  'supportive': 40214,
#  'security': 37257,
#  'better': 5654,
#  'nutrition': 29222,
#  'sensitive': 37452,
#  'can': 7121,
#  'give': 18130,
#  'consumers': 9783,
#  'options': 29885,
#  'ultimately': 42666,
#  'it': 22504,
#  'choose': 8212,
#  'they': 41339,
#  'eat': 13689,
#  'influences': 21378,
#  'own': 30423,
#  'nutritional': 29223,
#  'outcomes': 30166,
#  'sends': 37426,
#  'signals': 38016,
#  'back': 4916,
#  'through': 41433,
#  'system': 40534,
#  'retailers': 35640,
#  'processors': 33017,
#  'producers': 33038,
#  'shape': 37715,
#  'produced': 33036,
#  'how': 20017,
#  'sustainably': 40340,
#  'war': 44527,
#  'terror': 41122,
#  'framework': 17173,
#  'international': 21975,
#  'law': 24180,
#  'helen': 19403,
#  'duffy': 13478,
#  'cambridge': 7083,
#  'university': 43197,
#  'press': 32776,
#  'pp': 32453,
#  'li': 24578,
#  '488': 1230,
#  'poses': 32289,
#  'increasingly': 21084,
#  'intractable': 22115,
#  'challenges': 7908,
#  'legal': 24358,
#  'order': 29915,
#  'commentators': 9013,
#  'query': 33811,
#  'whether': 44891,
#  'reaction': 34242,
#  '11': 142,
#  'might': 26781,
#  'relaxed': 35045,
#  'or': 29892,
#  'transformed': 42027,
#  'well': 44789,
#  'established': 15167,
#  'principles': 32891,
#  'particularly': 30812,
#  'fields': 16435,
#  'recourse': 34549,
#  'force': 16915,
#  'state': 39302,
#  'responsibility': 35559,
#  'other': 30114,
#  'scholars': 36960,
#  'opine': 29821,
#  'adequately': 2388,
#  'suited': 40063,
#  'address': 2366,
#  'relatively': 35036,
#  'polymorphous': 32155,
#  'threats': 41418,
#  'terrorism': 41123,
#  'regardless': 34821,
#  'one': 29715,
#  'stance': 39234,
#  'question': 33813,
#  'clear': 8528,
#  'current': 10873,
#  'has': 19159,
#  'generated': 17855,
#  'considerable': 9657,
#  'academic': 2062,
#  'writing': 45293,
#  'inside': 21614,
#  'outside': 30223,
#  'propelled': 33249,
#  'various': 43837,
#  'issues': 22495,
#  'application': 3840,
#  'human': 20123,
#  'rights': 35950,
#  'humanitarian': 20131,
#  'criminal': 10578,
#  'forefront': 16939,
#  'scholarly': 36959,
#  'inquiry': 21578,
#  'rates': 34123,
#  'appear': 3815,
#  'where': 44884,
#  'participation': 30801,
#  'there': 41299,
#  'possible': 32331,
#  'relationship': 35032,
#  'drug': 13406,
#  'disability': 12514,
#  'this': 41378,
#  'may': 26093,
#  'arise': 4090,
#  'after': 2662,
#  'definition': 11490,
#  'was': 44573,
#  'extended': 15794,
#  'include': 21020,
#  'chronic': 8252,
#  'conditions': 9441,
#  'krueger': 23755,
#  '2017': 684,
#  '47': 1211,
#  'around': 4132,
#  'fifth': 16443,
#  'non': 28784,
#  'participating': 30800,
#  'prime': 32869,
#  'age': 2691,
#  'males': 25577,
#  'were': 44815,
#  'regularly': 34906,
#  'taking': 40667,
#  'opioid': 29827,
#  'painkillers': 30547,
#  'contrast': 9932,
#  'share': 37720,
#  'households': 20002,
#  'man': 25631,
#  'remained': 35105,
#  'stable': 39181,
#  '76': 1552,
#  'over': 30253,
#  'most': 27551,
#  'panel': 30627,
#  'germany': 17959,
#  'nevertheless': 28502,
#  'witnessed': 45111,
#  'significant': 38027,
#  'decline': 11336,
#  'about': 1942,
#  '15': 269,
#  'percentage': 31247,
#  'employment': 14399,
#  'among': 3352,
#  'during': 13539,
#  'period': 31304,
#  'worker': 45196,
#  'spain': 38842,
#  'instance': 21666,
#  '1995': 524,
#  'only': 29736,
#  '22': 814,
#  '25': 863,
#  'had': 18889,
#  'woman': 45149,
#  'full': 17423,
#  'year': 45449,
#  'compared': 9135,
#  '42': 1155,
#  '52': 1288,
#  'crisis': 10601,
#  'dutch': 13550,
#  'weeks': 44747,
#  'per': 31236,
#  'though': 41404,
#  'not': 28988,
#  'hours': 19996,
#  'week': 44742,
#  'parents': 30731,
#  'pay': 30999,
#  'maximum': 26091,
#  'fee': 16239,
#  'kindergarten': 23479,
#  'total': 41800,
#  'costs': 10272,
#  '2011': 618,
#  'depending': 11811,
#  'public': 33516,
#  'private': 32938,
#  'counties': 10348,
#  'responsible': 35562,
#  'upper': 43470,
#  'secondary': 37197,
#  'which': 44893,
#  'finance': 16504,
#  'taxes': 40814,
#  'block': 6015,
#  'grants': 18473,
#  'vary': 43843,
#  'considerably': 9659,
#  'region': 34846,
#  'another': 3614,
#  'additional': 2359,
#  'subsidies': 39914,
#  'provisions': 33403,
#  'given': 18131,
#  'avoid': 4800,
#  'regional': 34849,
#  'disparities': 12763,
#  'kindergartens': 23480,
#  '50': 1263,
#  'all': 3066,
#  'financed': 16506,
#  'municipalities': 27866,
#  'abstract': 1978,
#  'paper': 30659,
#  'demonstrates': 11707,
#  'different': 12333,
#  'scientific': 37014,
#  'disciplines': 12594,
#  'successfully': 39991,
#  'merged': 26513,
#  'efficient': 13992,
#  'life': 24667,
#  'applications': 3841,
#  'we': 44683,
#  'propose': 33276,
#  'novel': 29044,
#  'approach': 3890,
#  'social': 38540,
#  'science': 37008,
#  'using': 43611,
#  'artificial': 4195,
#  'intelligence': 21823,
#  'suggesting': 40039,
#  'neural': 28478,
#  'network': 28462,
#  'designto': 11983,
#  'anticipate': 3670,
#  'predict': 32620,
#  'perceptions': 31254,
#  'regarding': 34820,
#  'cyprus': 10982,
#  'conflict': 9506,
#  'peace': 31065,
#  'mediation': 26297,
#  'process': 33012,
#  'our': 30151,
#  'model': 27204,
#  'based': 5226,
#  'associating': 4383,
#  'views': 44117,
#  'thoughts': 41407,
#  'critical': 10610,
#  'related': 35023,
#  'together': 41660,
#  'anticipation': 3674,
#  'securing': 37246,
#  'treaty': 42170,
#  '2020': 709,
#  'database': 11146,
#  'collected': 8877,
#  'completed': 9214,
#  'surveys': 40303,
#  'relations': 35031,
#  'department': 11790,
#  'students': 39736,
#  'near': 28286,
#  'east': 13680,
#  'obtained': 29377,
#  'digitally': 12379,
#  'coded': 8731,
#  'values': 43780,
#  'entire': 14749,
#  'associative': 4387,
#  'predicting': 32625,
#  'further': 17488,
#  'used': 43588,
#  'training': 41955,
#  'testing': 41156,
#  'certainly': 7798,
#  'waives': 44466,
#  'way': 44646,
#  'rare': 34100,
#  'area': 4041,
#  'those': 41403,
#  'individuals': 21215,
#  'pocket': 32011,
#  'expenses': 15683,
#  '78': 1569,
#  'income': 21040,
#  'rural': 36435,
#  'even': 15399,
#  'insurance': 21767,
#  'decade': 11260,
#  '2003': 565,
#  'visits': 44233,
#  'township': 41852,
#  'medical': 26303,
#  'centres': 7747,
#  'hospitals': 19960,
#  'falling': 16015,
#  'while': 44895,
#  'urban': 43513,
#  'similar': 38096,
#  'institution': 21701,
#  'did': 12298,
#  'exist': 15613,
#  'schemes': 36932,
#  'accompanied': 2127,
#  'strategy': 39615,
#  'orient': 29989,
#  'existing': 15622,
#  'create': 10520,
#  'community': 9099,
#  'neighbourhood': 28384,
#  'committee': 9046,
#  'alastair': 2967,
#  'wood': 45162,
#  'co': 8679,
#  'ordinated': 29930,
#  'production': 33045,
#  'maria': 25818,
#  'consolati': 9683,
#  'louis': 25151,
#  'scott': 37051,
#  'provided': 33383,
#  'invaluable': 22172,
#  'secretariat': 37212,
#  'assistance': 4370,
#  'example': 15499,
#  'majority': 25532,
#  'principally': 32882,
#  'dependent': 11809,
#  'agriculture': 2781,
#  'turn': 42475,
#  'society': 38561,
#  'farmers': 16081,
#  'managing': 25649,
#  'land': 23993,
#  'sustain': 40335,
#  'supplies': 40206,
#  'biodiversity': 5822,
#  'environmental': 14813,
#  'services': 37560,
#  'relationships': 35034,
#  'dynamic': 13597,
#  'intense': 21836,
#  'climate': 8569,
#  'rising': 35999,
#  'resource': 35519,
#  'scarcities': 36879,
#  'price': 32848,
#  'volatilities': 44326,
#  'put': 33661,
#  'them': 41254,
#  'pressure': 32782,
#  'present': 32743,
#  'case': 7391,
#  'lcoe': 24236,
#  'calculated': 7027,
#  'including': 21025,
#  'carbon': 7257,
#  'usd': 43572,
#  '30': 967,
#  'tonne': 41728,
#  'co2': 8680,
#  'advantage': 2505,
#  'nuclear': 29152,
#  'energy': 14571,
#  'context': 9855,
#  'cost': 10254,
#  'remains': 35107,
#  'light': 24686,
#  'changes': 7947,
#  'fuel': 17395,
#  'particular': 30807,
#  'protected': 33336,
#  'against': 2678,
#  'low': 25167,
#  'proportion': 33266,
#  'lifetime': 24679,
#  'power': 32437,
#  'generation': 17858,
#  'overnight': 30331,
#  'construction': 9745,
#  'contingency': 9877,
#  'exclude': 15540,
#  'idc': 20442,
#  'builds': 6743,
#  'nine': 28673,
#  'years': 45455,
#  'basic': 5239,
#  'six': 38232,
#  'three': 41419,
#  'junior': 22986,
#  'entering': 14733,
#  'senior': 37431,
#  'attend': 4541,
#  'either': 14074,
#  'academically': 2063,
#  'oriented': 29997,
#  'vocational': 44294,
#  'applies': 3845,
#  'islamic': 22447,
#  'formal': 16997,
#  'comprises': 9279,
#  'general': 17832,
#  'sekolah': 37345,
#  'menengah': 26446,
#  'atas': 4456,
#  'sma': 38403,
#  'kejuruan': 23293,
#  'smk': 38448,
#  'schools': 36974,
#  'madrasah': 25433,
#  'aliyah': 3059,
#  'ma': 25352,
#  'mak': 25535,
#  'chapter': 7970,
#  'concentrates': 9346,
#  'largely': 24080,
#  'provision': 33398,
#  'considers': 9666,
#  'side': 37979,
#  'develop': 12129,
#  'colleges': 8897,
#  'alternative': 3203,
#  'routes': 36286,
#  'introduction': 22146,
#  'structures': 39718,
#  'standard': 39238,
#  'reasonable': 34326,
#  'person': 31389,
#  'resultant': 35622,
#  'luck': 25238,
#  'liability': 24580,
#  'criminalizing': 10588,
#  'sm': 38402,
#  'disavowing': 12564,
#  'erotic': 15025,
#  'instantiating': 21673,
#  'violence': 44187,
#  'constitutionalism': 9720,
#  'crime': 10573,
#  'form': 16994,
#  'moral': 27471,
#  'judgment': 22940,
#  'euthanasia': 15355,
#  'assisted': 4373,
#  'suicide': 40051,
#  'abnormal': 1919,
#  'teratology': 41065,
#  'logic': 25019,
#  'criminalization': 10584,
#  'tensions': 41042,
#  'empirical': 14381,
#  'desert': 11958,
#  'changing': 7948,
#  'norms': 28961,
#  'rape': 34074,
#  'reform': 34759,
#  '10': 100,
#  'preparation': 32711,
#  'offences': 29501,
#  'interests': 21919,
#  'political': 32087,
#  'freedom': 17232,
#  'last': 24103,
#  'since': 38135,
#  '2010': 603,
#  'discharges': 12588,
#  'capita': 7205,
#  'tended': 41017,
#  'decrease': 11373,
#  'line': 24768,
#  'oecd': 29476,
#  'mentioned': 26476,
#  'previously': 32841,
#  'dwellers': 13570,
#  'represent': 35340,
#  '43': 1166,
#  '32': 1002,
#  'hospital': 19953,
#  'attendances': 4543,
#  'absence': 1956,
#  'information': 21402,
#  'determine': 12077,
#  'difference': 12329,
#  'populations': 32232,
#  'if': 20524,
#  'so': 38521,
#  'drivers': 13380,
#  'geographic': 17909,
#  'cultural': 10825,
#  'infrastructural': 21424,
#  'data': 11144,
#  'patient': 30932,
#  'would': 45254,
#  'aid': 2853,
#  'understanding': 42921,
#  'remedies': 35132,
#  'barriers': 5199,
#  'overall': 30257,
#  'available': 4761,
#  'socio': 38563,
#  'economic': 13795,
#  'play': 31888,
#  'reaching': 34238,
#  'gates': 17701,
#  'admitted': 2460,
#  'uneven': 43021,
#  'probably': 32978,
#  'stems': 39402,
#  'inability': 20924,
#  'facilities': 15918,
#  'provide': 33382,
#  'examines': 15496,
#  'effects': 13979,
#  'child': 8138,
#  'early': 13649,
#  'forced': 16917,
#  'marriages': 25892,
#  'cefm': 7665,
#  'within': 45106,
#  'commonwealth': 9063,
#  'specific': 38908,
#  'focus': 16806,
#  'africa': 2647,
#  'highlights': 19610,
#  'best': 5639,
#  'issue': 22493,
#  'national': 28132,
#  'judicial': 22946,
#  'processes': 33014,
#  'currently': 10874,
#  'place': 31810,
#  'african': 2648,
#  'kenya': 23334,
#  'rwanda': 36467,
#  'uganda': 42612,
#  'tanzania': 40737,
#  'then': 41262,
#  'followed': 16850,
#  'background': 4926,
#  'section': 37225,
#  'gives': 18134,
#  'historical': 19708,
#  'overview': 30401,
#  'global': 18175,
#  'respond': 35541,
#  'psv': 33462,
#  'encouraged': 14484,
#  'strong': 39703,
#  'links': 24799,
#  'enterprises': 14736,
#  'cover': 10420,
#  'remote': 35161,
#  'cater': 7484,
#  'less': 24482,
#  'affluent': 2617,
#  'analyses': 3426,
#  'impact': 20766,
#  'dual': 13446,
#  'universities': 43196,
#  'australia': 4674,
#  'short': 37874,
#  'cycle': 10962,
#  'scotland': 37049,
#  'sub': 39781,
#  'sectors': 37233,
#  'tertiary': 41131,
#  'emerging': 14323,
#  'italy': 22510,
#  'discusses': 12667,
#  'transition': 42049,
#  'collaboration': 8853,
#  'ofpost': 29563,
#  'analysis': 3428,
#  'policy': 32070,
#  'negative': 28347,
#  'effect': 13972,
#  'decentralization': 11296,
#  'implemented': 20823,
#  '2001': 559,
#  'corruption': 10232,
#  'too': 41739,
#  'become': 5378,
#  'decentrali': 11292,
#  'zed': 45602,
#  'especially': 15121,
#  'west': 44825,
#  'java': 22715,
#  'article': 4182,
#  'patterns': 30966,
#  'probable': 32977,
#  'causes': 7523,
#  'government': 18386,
#  'officials': 29527,
#  'solution': 38669,
#  'do': 13040,
#  'just': 23021,
#  'author': 4687,
#  'chose': 8221,
#  'ocio': 29436,
#  'depth': 11874,
#  'interview': 22075,
#  'main': 25493,
#  'orruption': 30048,
#  'mostly': 27554,
#  'took': 41740,
#  'budget': 6714,
#  'misappropriation': 27003,
#  'major': 25526,
#  'source': 38783,
#  'abuse': 2048,
#  'money': 27373,
#  'politics': 32104,
#  'tendency': 41020,
#  'misuse': 27088,
#  'loopholes': 25100,
#  'regulations': 34912,
#  'enforcement': 14587,
#  'therefore': 41304,
#  'betterment': 5655,
#  'regulation': 34911,
#  'organizational': 29977,
#  'structure': 39716,
#  'officers': 29522,
#  'unequal': 43011,
#  'like': 24703,
#  'south': 38795,
#  'brazil': 6454,
#  'proportions': 33272,
#  'believe': 5478,
#  'incomes': 21042,
#  'made': 25425,
#  'equal': 14916,
#  'shift': 37810,
#  'preferences': 32657,
#  'towards': 41842,
#  'redistribution': 34650,
#  'brics': 6535,
#  'shown': 37912,
#  '12': 176,
#  'forthcoming': 17061,
#  'few': 16386,
#  'late': 24113,
#  '1980s': 499,
#  'course': 10387,
#  'view': 44112,
#  'says': 36839,
#  'little': 24873,
#  'preferred': 32661,
#  'method': 26600,
#  'achieving': 2212,
#  'attitudes': 4569,
#  'translate': 42060,
#  'into': 22105,
#  'concrete': 9403,
#  'tax': 40809,
#  'transfer': 42010,
#  'part': 30782,
#  'contract': 9905,
#  'every': 15419,
#  'country': 10363,
#  'stigma': 39466,
#  'attached': 4516,
#  'welfare': 44786,
#  'recipients': 34445,
#  'increases': 21081,
#  'disadvantage': 12518,
#  'similarly': 38099,
#  'dignity': 12391,
#  'recognition': 34475,
#  'wrongs': 45305,
#  'cause': 7521,
#  '54': 1306,
#  'undervaluing': 42949,
#  'wrong': 45299,
#  'directly': 12492,
#  'hence': 19447,
#  'right': 35946,
#  'value': 43777,
#  'synthesis': 40512,
#  'dimensions': 12423,
#  'equality': 14923,
#  'redressing': 34660,
#  'addressing': 2370,
#  'stereotyping': 39428,
#  'step': 39408,
#  'taken': 40659,
#  'cescr': 7817,
#  'cedaw': 7645,
#  'reporting': 35332,
#  'guidelines': 18755,
#  'para': 30677,
#  '29': 924,
#  'ecuador': 13847,
#  'op': 29765,
#  'bandung': 5089,
#  'city': 8401,
#  '44': 1178,
#  'revenue': 35751,
#  '2016': 669,
#  'expected': 15662,
#  'come': 8968,
#  'transfers': 42018,
#  'common': 9054,
#  'problem': 32986,
#  'ith': 22530,
#  'automatic': 4725,
#  'allocation': 3114,
#  'fund': 17448,
#  'partly': 30830,
#  'allocated': 3111,
#  'registered': 34867,
#  'governments': 18391,
#  'does': 13086,
#  'take': 40655,
#  'account': 2148,
#  'unregistered': 43304,
#  'high': 19600,
#  'much': 27726,
#  'true': 42332,
#  'damage': 11060,
#  'aftermath': 2665,
#  'disasters': 12560,
#  'undocumented': 42978,
#  'needs': 28331,
#  'explored': 15740,
#  'vulnerability': 44402,
#  'island': 22453,
#  'states': 39313,
#  'retreat': 35683,
#  'threat': 41413,
#  'option': 29881,
#  'risk': 36000,
#  'left': 24352,
#  'unattended': 42724,
#  'amount': 3360,
#  '70': 1491,
#  'cent': 7714,
#  'death': 11237,
#  'toll': 41689,
#  'arises': 4092,
#  'destruction': 12032,
#  'infrastructure': 21425,
#  'disruption': 12834,
#  'staff': 39192,
#  'discover': 12636,
#  'vital': 44248,
#  'elements': 14163,
#  'damaged': 11061,
#  'destroyed': 12029,
#  'beyond': 5674,
#  'effective': 13974,
#  'operational': 29791,
#  ...}

# %%
count_vector
# Out:
# <24669x45738 sparse matrix of type '<class 'numpy.int64'>'
# 	with 1647396 stored elements in Compressed Sparse Row format>

# %%
count_vectorizer.get_stop_words()

# %%
count_vectorizer.get_feature_names_out()
# Out:
# array(['00', '000', '0000002', ..., 'œopen', 'ʿadawiyya', '四个全面'],
#       dtype=object)

# %%
import re

# %%
t1
# Out:
# 'In China today,President Xi Jinping’s new grand narrative is framed by the widely publicised ‘four comprehensives’ (四个全面, ‘sigequanmian’). This narrative aims to : 1.build a moderately prosperous society, 2. deepen reform, 3. govern the nation according to law, and 4. tighten Party discipline. It is essentially a political narrative that tells a moral tale that legitimizes and glorifies the virtues of the present. It also attempts to shrug off mistakes of the previous dynasty. Drawing on the legal disciplines of economic law, international comparative law and the a priori analytic method of legal narrative analysis, this paper provides a critical appraisal of the ‘four comprehensives’, paying special attention to how the four principal strands of the narrative shape the directions of China’s socialist rule of law reforms and governance.  Key words: Chinese law reform, four comprehensives, 四个全面, sigequanmian,socialist rule of law,legal narrative analysis, economic-law nexus, South China Sea.'

# %%
print(re.search(r'China', t1))
print(re.search(r'[a-z]\,',t1))
# Out:
# <re.Match object; span=(3, 8), match='China'>
# <re.Match object; span=(13, 15), match='y,'>

# %%
from nltk import word_tokenize, sent_tokenize
docs_str = docs.str.cat()
tokens = word_tokenize(docs_str)
len(tokens), len(set(tokens))
# Out:
# (2628532, 83735)

# %%
from nltk import collocations
fd = collocations.FreqDist(tokens)
fd.most_common(30)
# Out:
# [(',', 130689),
#  ('the', 126635),
#  ('of', 95441),
#  ('and', 92697),
#  ('.', 69566),
#  ('to', 63693),
#  ('in', 59083),
#  ('a', 33126),
#  ('for', 27726),
#  ('(', 26075),
#  (')', 25135),
#  ('is', 25113),
#  ('that', 20236),
#  ('are', 18153),
#  ('on', 17660),
#  ('as', 17215),
#  ('with', 13771),
#  ('by', 13633),
#  ('be', 12592),
#  ('The', 12564),
#  ('from', 9589),
#  ('have', 9048),
#  ('or', 8979),
#  ('has', 7529),
#  ('not', 7481),
#  ('this', 7474),
#  ('an', 7415),
#  ('countries', 7244),
#  ('their', 7212),
#  ('’', 7012)]

# %%
measures = collocations.BigramAssocMeasures()
c = collocations.BigramCollocationFinder.from_words(tokens)
c.nbest(measures.pmi,100)
# Out:
# [("'Camikavas", 'negi'),
#  ("'Necessary", 'Thickening'),
#  ("'PES-like", "fashion'and"),
#  ("'Paris", "rulebook'.This"),
#  ("'any", 'electrically'),
#  ("'ex", 'turpi'),
#  ("'family", "values'.To"),
#  ("'nine", 'gems'),
#  ('-16.58', 'p.p.'),
#  ('-Midia', 'Navodari'),
#  ('-at', 'times-also'),
#  ('-chronically-ill', 'people-'),
#  ('-red', 'ressing'),
#  ('.95.5', '95.3'),
#  ('.Case', 'Closed'),
#  ('.Definiciones', 'Instrumentos'),
#  ('.Minimum', 'wages—which'),
#  ('//climatepolicyinitiative.org/', 'wp-content/uploads/2015/05/150512'),
#  ('//data.uJorldbank.org/', 'about/country-classifications'),
#  ('//documents.worldbank.org/curated/en/552891468229171088/Cambodia-Nutrition-at-a-g',
#   'lance'),
#  ('//doi.org/10.1080/', '07900627.2017.1401919'),
#  ('//dx.doi.org/10.1787/', 'sti_scoreboard-2013-en'),
#  ('//ec.euroDa.cu/soc', 'ial/BlobServlcl'),
#  ('//economictimes.indiatimes.com/',
#   'news/politics-and-nation/indias-renewable-energy-targets-catch-the-attention-of-global-investors-still-need-ground-work/articleshow/53015707.cms'),
#  ('//enviroscope.iges.or.jp/contents/APEIS/RISPO/inventory/',
#   'db/pdf/0097.pdf'),
#  ('//eur-lex.europa.eu/LexUriSeru/', 'LexUriServ.do'),
#  ('//facultv.haas.berkelev.edU/wolfram/P', 'apers/paper_draft_06_'),
#  ('//minorityrights.org/',
#   'wp-content/uploads/old-site-downloads/download-150-Batwa-Pygmies-of-the-Great-Lakes-Region.pdf'),
#  ('//science.sciencemag.org/content/sci/309/', '5742/1844.full.pdf'),
#  ('//stalcubc.at/statistik.at/cxt/statcubc/isf/tablcVicw/tablc', 'View.xhtml'),
#  ('//totalspectrumsaa.com/press/erik-autor-testifies-on-l3cev-act-fehruarv-2014',
#   'IINAS'),
#  ('//unfccc.int/national_reports/',
#   'annex_i_natcom/submitted_natcom/items/4903.php'),
#  ('//w', 'ww.ihei.org/wn-conieni/unloads/2014A'),
#  ('//www.academia.edu/2755320/Nation-al_Infrastructure_Planning_A_Holistic_Approach_',
#   'to_Policy_Development_in_Developing_Countries'),
#  ('//www.africa-union.org/root/au/conferences/past/2006/may/summit/doc/en/',
#   'UNGASS_Common_Position.pdf'),
#  ('//www.ccamlr.0rg/pu/e/', 'cds/intro.htm'),
#  ('//www.e-unwto.org/doi/', 'pdf/10.18111/9789284418145'),
#  ('//www.envir.ee/orb.aw/class=file/',
#   'action=preview/id=1187006/Eesti+elanike+keskkonnateadlikkus2012aruanne'),
#  ('//www.eri.chula.ac.th/eri-main/wp-content/upIoads/2016/01/Thailand-Renewable-Development-Status-and-Recommendations',
#   'Tongsopit.pdf.In'),
#  ('//www.eurasia.undp.org/content/rbec/en/home/library/environment_energy/',
#   'Development_stories_from_Europe_and_Central_Asia_Volume_lll.html'),
#  ('//www.fao.org/', 'worldfoodsituation/wfs-home/foodpricesindex/en'),
#  ('//www.ilo.org/employment/areas/',
#   'youth-employment/WCMS_627307/lang—en/index.htm.There'),
#  ('//www.ilo.org/sapfl/lnformationresources/Factsheetsandbroch',
#   'ures/WCMS_105036/lang-en/index.htm'),
#  ('//www.ilo.org/tocmsp5/',
#   'groups/public/—ed_norm/—reteonfcrdocuments/meetingdocument/wcms_157834.pdf'),
#  ('//www.ilo.org/wcmsp5/groups/public/-dgreports/—dcomm/—publ/',
#   'documents/publication/wcms_513739.pdf'),
#  ('//www.imshealth.com/deployedfiles/imshealth/Global/Content/Corporate/IMS',
#   'Institute/RUOM-2013/IHII_Responsible_Use_Medicines_2013.pdf'),
#  ('//www.inatsisartut.gl/',
#   'inatsisartuthome/sammensaetning-af-inatsisartut.aspx'),
#  ('//www.itu.int/en/ITU-D/',
#   'Statistics/Pages/intlcoop/partnership/members.aspx'),
#  ('//www.nab.vu/sites/default/',
#   'files/nab/vanuatu_cc_drr_policy_minus_att4v4.pdf'),
#  ('//www.nordicenergysolutions.org', 'Orkustofnun'),
#  ('//www.un.org/development/desa/dpad/wp-content/uploads/sites/45/',
#   'publication/2017_Aug_Frontier-Issues-l.pdf'),
#  ('//www.whoindia.org/LinkFiles/Commision_on_',
#   'Macroeconomic_and_Health_01_01.pdf'),
#  ('/Users/thevenon', 'o/Downloads/4448-157-5923-l-10-20180213.pdf'),
#  ('/technical', 'recommendations.Iraq'),
#  ('0.102', '3/A'),
#  ('0.70', 'manat/'),
#  ('099', '26858'),
#  ('0rganik', 'Granular'),
#  ('1,500-2,500', 'rial'),
#  ('1,858', 'KWh/m2yr'),
#  ('10.111', 'l/conl.12180'),
#  ('1184', 'LUEPs'),
#  ('120-150', 'kg/person/year'),
#  ('1240', 'MW.Albert'),
#  ('126-12', '745'),
#  ('14.39', 'million.Given'),
#  ('14/FIN', 'AL'),
#  ('16-19', 'bursary'),
#  ('16-75', 'households.At'),
#  ('16USC', '755-757'),
#  ('17-year-old', 'fiance'),
#  ('18.74', 'million.Government'),
#  ('18—a', 'pra'),
#  ('1980s.Chinese', 'Atademy'),
#  ('1998-the', 'hottest'),
#  ('2,025', 'phe-nobarbital'),
#  ('2,315', 'yuan'),
#  ('2,582', 'MCM.3'),
#  ('2.47', 'acres.As'),
#  ('20-23', 'MCM/yr45'),
#  ('2000-', '2010.Such'),
#  ('2002a', 'p.iii'),
#  ('2007/08.This', 'reprioritization'),
#  ('2008-June', '2009.There'),
#  ('2009.A', 'reanalysis'),
#  ('2011-2019', 'MOWA'),
#  ('2012-A', 'Look'),
#  ('2014–2019', 'recontextualised'),
#  ('2017—a', '41-per'),
#  ('224,000', 'ha.Building'),
#  ('270,000', 'ha.37'),
#  ('294.4', 'million.The'),
#  ('3.4°C', 'warming.317'),
#  ('3.6308', 'ha-m/100'),
#  ('3.7.This', 'refoim'),
#  ('31.28', 'exajoules'),
#  ('371', 'kWh.This'),
#  ('395per', 'USD.The'),
#  ('4,942', 'Megawatts'),
#  ('42.1-km', 'Jabodebek')]

# %%
measures

# %%
# http://wordnetweb.princeton.edu/perl/webwn?s=good&sub=Search+WordNet&o2=&o0=1&o8=1&o1=1&o7=&o5=&o9=&o6=&o3=&o4=&h=

from nltk.corpus import wordnet

# %%
wordnet.synsets('dig'),wordnet.synsets('dig', pos=wordnet.VERB)
# Out:
# ([Synset('dig.n.01'),
#   Synset('shot.n.09'),
#   Synset('dig.n.03'),
#   Synset('excavation.n.01'),
#   Synset('dig.n.05'),
#   Synset('dig.v.01'),
#   Synset('dig.v.02'),
#   Synset('labor.v.02'),
#   Synset('dig.v.04'),
#   Synset('dig.v.05'),
#   Synset('excavate.v.04'),
#   Synset('jab.v.01'),
#   Synset('grok.v.01')],
#  [Synset('dig.v.01'),
#   Synset('dig.v.02'),
#   Synset('labor.v.02'),
#   Synset('dig.v.04'),
#   Synset('dig.v.05'),
#   Synset('excavate.v.04'),
#   Synset('jab.v.01'),
#   Synset('grok.v.01')])

# %%
synonyms = []
antonyms = []

for syn in wordnet.synsets("good"):
    for l in syn.lemmas():
        synonyms.append(l.name())
        if l.antonyms():
            antonyms.append(l.antonyms()[0].name())

print(set(synonyms))
print(set(antonyms))
# Out:
# {'upright', 'ripe', 'skilful', 'dear', 'right', 'well', 'soundly', 'effective', 'near', 'in_effect', 'goodness', 'sound', 'full', 'serious', 'good', 'secure', 'practiced', 'unspoiled', 'thoroughly', 'proficient', 'estimable', 'salutary', 'adept', 'commodity', 'undecomposed', 'expert', 'safe', 'honorable', 'respectable', 'honest', 'in_force', 'dependable', 'unspoilt', 'just', 'trade_good', 'skillful', 'beneficial'}
# {'ill', 'bad', 'evil', 'badness', 'evilness'}

# %%
syns = wordnet.synsets("good")

# %%
syns[0].examples()
# Out:
# ['for your own good', "what's the good of worrying?"]

# %%
w1 = wordnet.synset('ship.n.01')
w2 = wordnet.synset('boat.n.01')
w3 = wordnet.synset('car.n.01')
w4 = wordnet.synset('cat.n.01')
print(w1.wup_similarity(w2)), print(w1.wup_similarity(w3)),print(w1.wup_similarity(w4)),print(w2.wup_similarity(w3)), print(w2.wup_similarity(w4)), print(w3.wup_similarity(w4))
# Out:
# 0.9090909090909091
# 0.6956521739130435
# 0.32
# 0.6956521739130435
# 0.32
# 0.32
# (None, None, None, None, None, None)
